# %% [markdown]
# <a href="https://colab.research.google.com/github/Forrward/LABbl/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Задание 1.1

import pandas as pd
import numpy as np

df = pd.read_excel("vigr_9_apr.xlsx")
df
# Out:
#       № п/п      №\nдокумента Дата\nрегистрации              Исх. №\nДата  \
# 0         1    WSR/1-838/2019        2019-04-09       208-409\n08.04.2019
# 1         2    WSR/1-837/2019        2019-04-09        05-338\n09.04.2019
# 2         3    WSR/1-835/2019        2019-04-09   И10-14/3137\n09.04.2019
# 3         4    WSR/1-834/2019        2019-04-09    Д2/7121-ИС\n03.04.2019
# 4         5    WSR/1-833/2019        2019-04-09  15-20/06-911\n08.04.2019
# ...     ...               ...               ...                       ...
# 4962   4963  WSR/1.-1749/2017        2017-11-01            11\n20.10.2017
# 4963   4964  WSR/1.-1751/2017        2017-11-01    ТС-1164/06\n31.10.2017
# 4964   4965  WSR/1.-1748/2017        2017-11-01                ЛО-95/06пр
# 4965   4966  WSR/1.-1747/2017        2017-11-01    ЛО-93/06пр\n24.10.2017
# 4966   4967               NaN               NaT   НА-29/15077\n18.10.2017
#
#           Адресат                                              Автор  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   № п/п               4967 non-null   int64
#  1   №
# документа         4965 non-null   object
#  2   Дата
# регистрации    4965 non-null   datetime64[ns]
#  3   Исх. №
# Дата         4967 non-null   object
#  4   Адресат             4967 non-null   object
#  5   Автор               4967 non-null   object
#  6   Краткое
# содержание  4967 non-null   object
#  7   Примечание          308 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 310.6+ KB

# %%
df.describe()
# Out:
#              № п/п
# count  4967.000000
# mean   2484.000000
# std    1433.993724
# min       1.000000
# 25%    1242.500000
# 50%    2484.000000
# 75%    3725.500000
# max    4967.000000

# %%
df.columns
# Out:
# Index(['№ п/п', '№\nдокумента', 'Дата\nрегистрации', 'Исх. №\nДата', 'Адресат',
#        'Автор', 'Краткое\nсодержание', 'Примечание'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# № п/п                     0
# №\nдокумента              2
# Дата\nрегистрации         2
# Исх. №\nДата              0
# Адресат                   0
# Автор                     0
# Краткое\nсодержание       0
# Примечание             4659
# dtype: int64

# %%
#Удаляем данные столбцы , т.к. они не нужны
df = df.drop(columns = ['№\nдокумента','Дата\nрегистрации','Исх. №\nДата'],axis = 1)
df
# Out:
#       № п/п      Адресат                                              Автор  \
# 0         1  Уразов Р.Н.                     Антонова С.В. (АО «Интерфакс»)
# 1         2  Уразов Р.Н.  Картошкин С.А. (Министерство просвещения Росси...
# 2         3  Уразов Р.Н.   Цивилев С.Е. (Администрация Кемеровской области)
# 3         4  Иванюк Л.А.  Волков Г.А. (Министерство транспорта Российско...
# 4         5  Уразов Р.Н.  Атанов И.В. (Ставропольский государственный аг...
# ...     ...          ...                                                ...
# 4962   4963  Уразов Р.Н.  Медведев Д.А. (Аппарат Правительства Российско...
# 4963   4964  Уразов Р.Н.  Синюгина Т.Ю. (Министерство образования и наук...
# 4964   4965  Уразов Р.Н.  Огородова Л.М. (Министерство образования и нау...
# 4965   4966  Уразов Р.Н.  Огородова Л.М. (Министерство образования и нау...
# 4966   4967  Уразов Р.Н.  Асаул Н.А. (Министерство транспорта Российской...
#
# ...

# %%
#Удаляем т.к. в столбце "Примечание" 4659 пустых строк
df.drop("Примечание", axis = 1, inplace= True)
df
# Out:
#       № п/п      Адресат                                              Автор  \
# 0         1  Уразов Р.Н.                     Антонова С.В. (АО «Интерфакс»)
# 1         2  Уразов Р.Н.  Картошкин С.А. (Министерство просвещения Росси...
# 2         3  Уразов Р.Н.   Цивилев С.Е. (Администрация Кемеровской области)
# 3         4  Иванюк Л.А.  Волков Г.А. (Министерство транспорта Российско...
# 4         5  Уразов Р.Н.  Атанов И.В. (Ставропольский государственный аг...
# ...     ...          ...                                                ...
# 4962   4963  Уразов Р.Н.  Медведев Д.А. (Аппарат Правительства Российско...
# 4963   4964  Уразов Р.Н.  Синюгина Т.Ю. (Министерство образования и наук...
# 4964   4965  Уразов Р.Н.  Огородова Л.М. (Министерство образования и нау...
# 4965   4966  Уразов Р.Н.  Огородова Л.М. (Министерство образования и нау...
# 4966   4967  Уразов Р.Н.  Асаул Н.А. (Министерство транспорта Российской...
#
#                                     Краткое\nсодержание
# ...

# %%
df.dropna()
# Out:
#       № п/п      Адресат                                              Автор  \
# 0         1  Уразов Р.Н.                     Антонова С.В. (АО «Интерфакс»)
# 1         2  Уразов Р.Н.  Картошкин С.А. (Министерство просвещения Росси...
# 2         3  Уразов Р.Н.   Цивилев С.Е. (Администрация Кемеровской области)
# 3         4  Иванюк Л.А.  Волков Г.А. (Министерство транспорта Российско...
# 4         5  Уразов Р.Н.  Атанов И.В. (Ставропольский государственный аг...
# ...     ...          ...                                                ...
# 4962   4963  Уразов Р.Н.  Медведев Д.А. (Аппарат Правительства Российско...
# 4963   4964  Уразов Р.Н.  Синюгина Т.Ю. (Министерство образования и наук...
# 4964   4965  Уразов Р.Н.  Огородова Л.М. (Министерство образования и нау...
# 4965   4966  Уразов Р.Н.  Огородова Л.М. (Министерство образования и нау...
# 4966   4967  Уразов Р.Н.  Асаул Н.А. (Министерство транспорта Российской...
#
#                                     Краткое\nсодержание
# ...

# %%
#Задание 1.2

#Убираем из столбца "Автор" название компании, и добавляем новый столбец "Компания"
df['Компания'] = df['Автор'].str.extract(r'\((.*?)\)')
df['Автор'] = df['Автор'].str.replace(r'\([^)]*\)', '', regex=True)
df
# Out:
#       № п/п      Адресат            Автор  \
# 0         1  Уразов Р.Н.   Антонова С.В.
# 1         2  Уразов Р.Н.  Картошкин С.А.
# 2         3  Уразов Р.Н.    Цивилев С.Е.
# 3         4  Иванюк Л.А.     Волков Г.А.
# 4         5  Уразов Р.Н.     Атанов И.В.
# ...     ...          ...              ...
# 4962   4963  Уразов Р.Н.   Медведев Д.А.
# 4963   4964  Уразов Р.Н.   Синюгина Т.Ю.
# 4964   4965  Уразов Р.Н.  Огородова Л.М.
# 4965   4966  Уразов Р.Н.  Огородова Л.М.
# 4966   4967  Уразов Р.Н.      Асаул Н.А.
#
#                                     Краткое\nсодержание  \
# 0     Вх - О возможности использования сетевого изда...
# 1     Вх - Об участии в совещании по вопросу доработ...
# 2     Вх - О командировании Саликовой К. и Глушко Д....
# 3     Вх - Об участии в Чемпионате мира по профессио...
# 4     Вх - Об участии в церемонии открытия Вузовског...
# ...                                                 ...
# 4962  Протокол заседания Президиума Совета при Прези...
# ...

# %%
#Задание 1.3

#В данном задании нужно провести кластеризацию, но на выполнение этого задания уйдёт много времени, поэтому мы его пропускаем.
#Напишу план работы, который я бы использовал для выполнения данной задачи:
#Для того чтобы, провести кластеризацию нужно определить признаки, которые помогут распределить документы по кластерам.
#Рассмотрим следующие признаки:
#1) Адресат: Генеральный директор; сотрудники, обрабатывающие определенные типы документов.
#2) Автор: Первые лица министерств; организации с особым статусом отправителя.
#3) Краткое содержание: Ключевые слова или фразы, указывающие на особые типы документов или направление.
#4) Контекст: Информация из предыдущих писем, подсказывающая, кому направить новое письмо.
#После определения признаков используем различные методы кластеризации: k-means, DBSCAN или иерархическая кластеризация.
#Процесс включает выбор признаков, заполнение пропущенных значений, преобразование данных в числовой формат и применение методов кластеризации.

# %%
#Задание 1.4

from sklearn.feature_extraction.text import CountVectorizer
count = CountVectorizer()
#преобразование текста
count = count.fit_transform(df["Краткое\nсодержание"])
count = count.toarray()

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_copy = df.copy()

df_copy['target'] = le.fit_transform(df_copy['Адресат'])
df_copy['target'].unique()
# Out:
# array([143,  48,  71, 132,  57,   2,  18,   5,  73,  45,  76,  80,  92,
#        111,  60, 104,  36,  87,  32,  22,  75, 119, 118,  46,  47,  54,
#          6,  77,  40,  13,  96,   1, 155, 123,  79,  63,  37,  16, 137,
#         20,  50,  74, 110,  23, 129,  72,  43, 135,  38, 131, 127,  90,
#        144, 152,  59,  21,  51, 159,  28,  55,  56, 116,  35,  99,   9,
#         65,  98, 139,  58,  17,  25,  62,  78,  29,  11,  83, 156,  68,
#         49, 125,  97, 160,  19, 134,  84,  15, 114, 141, 138,  24, 136,
#         44,  86,  91, 102,  69, 103, 140,  88, 113,  34, 157, 124, 109,
#         82, 115,  66,   8,  30,  81,  64, 107, 121, 153, 120, 108,  10,
#        146,  12,  70,  39,  94, 122,   7,  33, 128,  89,   0,  93,  14,
#          4, 133, 142, 101, 126, 130, 117, 149,  27, 100,  95, 158,   3,
#         61,  42,  41, 112, 150, 148, 145,  31,  67, 105,  52,  85, 154,
#         26, 147, 151, 106,  53])

# %%
df_copy
# Out:
#       № п/п      Адресат            Автор  \
# 0         1  Уразов Р.Н.   Антонова С.В.
# 1         2  Уразов Р.Н.  Картошкин С.А.
# 2         3  Уразов Р.Н.    Цивилев С.Е.
# 3         4  Иванюк Л.А.     Волков Г.А.
# 4         5  Уразов Р.Н.     Атанов И.В.
# ...     ...          ...              ...
# 4962   4963  Уразов Р.Н.   Медведев Д.А.
# 4963   4964  Уразов Р.Н.   Синюгина Т.Ю.
# 4964   4965  Уразов Р.Н.  Огородова Л.М.
# 4965   4966  Уразов Р.Н.  Огородова Л.М.
# 4966   4967  Уразов Р.Н.      Асаул Н.А.
#
#                                     Краткое\nсодержание  \
# 0     Вх - О возможности использования сетевого изда...
# 1     Вх - Об участии в совещании по вопросу доработ...
# 2     Вх - О командировании Саликовой К. и Глушко Д....
# 3     Вх - Об участии в Чемпионате мира по профессио...
# 4     Вх - Об участии в церемонии открытия Вузовског...
# ...                                                 ...
# 4962  Протокол заседания Президиума Совета при Прези...
# ...

# %%
from sklearn.manifold import TSNE

couX_embedded = TSNE(n_components=2).fit_transform(count)


import matplotlib.pyplot as plt

plt.scatter(couX_embedded[:, 0], couX_embedded[:, 1],  c=[i for i, _ in enumerate(df.Адресат)])
plt.show()

# %%
import nltk
import re
from sklearn.feature_extraction.text import CountVectorizer
nltk.download("stopwords") #стоп-слова
nltk.download('punkt')
nltk.download('wordnet') #лемматизация

from nltk.corpus import stopwords

data_brif = df['Краткое\nсодержание']
new_data_brif = []
lemmatize = nltk.WordNetLemmatizer()

for i in data_brif:
    text = re.sub("[^a-zA-Z]"," ",i)
    text = nltk.word_tokenize(text,language = "russian") #токенизируем слова
    text = [lemmatize.lemmatize(word) for word in i] #лемматирзируем слова
    text = "".join(text) #соединяем слова
    new_data_brif.append(text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
