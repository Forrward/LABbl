# %% [markdown]
# <a href="https://colab.research.google.com/github/Forrward/LABbl/blob/main/lab3/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
def create_holes(dataframe, column_name, hole_percentage = 50):

    if hole_percentage < 0 or hole_percentage > 100:
        raise ValueError("Процент дырявости должен быть в диапазоне от 0 до 100.")

    dataframe_with_holes = dataframe.copy()
    num_holes = int(len(dataframe) * (hole_percentage / 100))
    hole_indices = np.random.choice(len(dataframe), num_holes, replace=False)
    dataframe_with_holes.loc[hole_indices, column_name] = np.nan

    return dataframe_with_holes

df_nan = df
df_nan = create_holes(df_nan, 'RestingBP')
df_nan
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0          289          0     Normal
# 1     49   F           NAP        NaN          180          0     Normal
# 2     37   M           ATA      130.0          283          0         ST
# 3     48   F           ASY      138.0          214          0     Normal
# 4     54   M           NAP      150.0          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        NaN          264          0     Normal
# 914   68   M           ASY        NaN          193          1     Normal
# 915   57   M           ASY      130.0          131          0     Normal
# 916   57   F           ATA      130.0          236          0        LVH
# 917   38   M           NAP      138.0          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Удаление
df_cleaned = df.dropna()
df_cleaned
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи медианы
df_median = df_nan.fillna(df_nan.median())
df_median
# Out:
# <ipython-input-15-50f5eac72eed>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_median = df_nan.fillna(df_nan.median())
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0          289          0     Normal
# 1     49   F           NAP      130.0          180          0     Normal
# 2     37   M           ATA      130.0          283          0         ST
# 3     48   F           ASY      138.0          214          0     Normal
# 4     54   M           NAP      150.0          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      130.0          264          0     Normal
# 914   68   M           ASY      130.0          193          1     Normal
# 915   57   M           ASY      130.0          131          0     Normal
# 916   57   F           ATA      130.0          236          0        LVH
# 917   38   M           NAP      138.0          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи среднего
df_mean = df_nan.fillna(df_nan.mean())
df_mean
# Out:
# <ipython-input-16-cd67a3110b20>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean = df_nan.fillna(df_nan.mean())
#      Age Sex ChestPainType   RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA  140.000000          289          0     Normal
# 1     49   F           NAP  132.978214          180          0     Normal
# 2     37   M           ATA  130.000000          283          0         ST
# 3     48   F           ASY  138.000000          214          0     Normal
# 4     54   M           NAP  150.000000          195          0     Normal
# ..   ...  ..           ...         ...          ...        ...        ...
# 913   45   M            TA  132.978214          264          0     Normal
# 914   68   M           ASY  132.978214          193          1     Normal
# 915   57   M           ASY  130.000000          131          0     Normal
# 916   57   F           ATA  130.000000          236          0        LVH
# 917   38   M           NAP  138.000000          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи моды
df_mode = df_nan.fillna(df_nan['RestingBP'].mode()[0])
df_mode
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA      140.0          289          0     Normal
# 1     49   F           NAP      130.0          180          0     Normal
# 2     37   M           ATA      130.0          283          0         ST
# 3     48   F           ASY      138.0          214          0     Normal
# 4     54   M           NAP      150.0          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA      130.0          264          0     Normal
# 914   68   M           ASY      130.0          193          1     Normal
# 915   57   M           ASY      130.0          131          0     Normal
# 916   57   F           ATA      130.0          236          0        LVH
# 917   38   M           NAP      138.0          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
#Заполнение при помощи интерполяции
df_interpolate = df_nan.fillna(df_nan.interpolate())
df_interpolate
# Out:
#      Age Sex ChestPainType   RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA  140.000000          289          0     Normal
# 1     49   F           NAP  135.000000          180          0     Normal
# 2     37   M           ATA  130.000000          283          0         ST
# 3     48   F           ASY  138.000000          214          0     Normal
# 4     54   M           NAP  150.000000          195          0     Normal
# ..   ...  ..           ...         ...          ...        ...        ...
# 913   45   M            TA  136.666667          264          0     Normal
# 914   68   M           ASY  133.333333          193          1     Normal
# 915   57   M           ASY  130.000000          131          0     Normal
# 916   57   F           ATA  130.000000          236          0        LVH
# 917   38   M           NAP  138.000000          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# **Объясните**

# %% [markdown]
# Объяснение:
#
# Сложность в работе с отсутствующими данными заключается в проблеме искажения статистики. Эти методы применимы только при малом количестве пропусков, поскольку большой процент отсутствующих данных может привести к искажению информации, а удаление - повлиять на итоговый результат. Важно понимать, для каких целей это делается. Хотя методы заполнения средними и медианными значениями являются приблизительными, они могут быть полезны для дальнейшей обработки данных.

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
#Методом среднего
mean_data = df["RestingBP"].mean()
maximum = mean_data * 2

df_mean = df[abs((df["RestingBP"] - mean_data) < maximum)]
df_mean["RestingBP"].describe()
# Out:
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64

# %%
#При помощи межквартильного размаха
Q1 =  df["RestingBP"].quantile(0.25)
Q3 = df["RestingBP"].quantile(0.75)
IQR = Q3 - Q1
df_IQR = df[(df["RestingBP"] > (Q1-1.5*IQR )) & (df["RestingBP"] < (Q3+1.5*IQR))]
df_IQR["RestingBP"].describe()
# Out:
# count    876.000000
# mean     130.492009
# std       15.176634
# min       92.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      165.000000
# Name: RestingBP, dtype: float64

# %%
#Статистика и объяснение
print(f' 1.Оригинал\n{df.describe()}\n\n 2.Метод среднего\n{df_mean["RestingBP"].describe()}\n\n 3.Межквартильный размах\n{df_IQR["RestingBP"].describe()}')
# Out:
#  1.Оригинал
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000
#
#  2.Метод среднего
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64
#
#  3.Межквартильный размах
# count    876.000000
# mean     130.492009
# std       15.176634
# min       92.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      165.000000
# Name: RestingBP, dtype: float64

# %% [markdown]
# **Объяснения**

# %% [markdown]
# Объяснение:
#
# Сравнение исходного датафрейма с методом среднего значения показывает наличие 8 выбросов, найденных на основе среднего значения и отклонения. Если же использовать медиану в качестве эталона, то можно увидеть, что выбросы определяются как элементы, выходящие за пределы интервала квартиля [Q25, Q75]. В этом случае количество выбросов больше, чем при использовании среднего значения

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли
df_duplicated = df[df.duplicated()]
df_duplicated
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
#Удаление дублей
df = df.drop_duplicates()
df_no_duplicates = df[df.duplicated()]
df_no_duplicates
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
num_features = df.select_dtypes(include=['float64']).columns
df_oldpeak = df.Oldpeak.unique()

print(f'{num_features}\n\n{df_oldpeak}')
# Out:
# Index(['Oldpeak'], dtype='object')
#
# [ 0.   1.   1.5  2.   3.   4.   0.5  2.5  5.   0.8  0.7  1.4  2.1  0.4
#   0.2  1.7  2.2  0.1  1.6  1.3  0.3  1.8  2.6 -0.9  2.8 -2.6 -1.5 -0.1
#   0.9  1.1  2.4 -1.  -1.1 -0.7 -0.8  3.7  1.2 -0.5 -2.   1.9  3.5  0.6
#   3.1  2.3  3.4  3.6  4.2  3.2  5.6  3.8  2.9  6.2  4.4]

# %%
# MinMaxScaler

scaler = MinMaxScaler()
df_scaler = df.copy()
df_scaler[num_features] = scaler.fit_transform(df[num_features])
df_scaler.Oldpeak.unique()
# Out:
# array([0.29545455, 0.40909091, 0.46590909, 0.52272727, 0.63636364,
#        0.75      , 0.35227273, 0.57954545, 0.86363636, 0.38636364,
#        0.375     , 0.45454545, 0.53409091, 0.34090909, 0.31818182,
#        0.48863636, 0.54545455, 0.30681818, 0.47727273, 0.44318182,
#        0.32954545, 0.5       , 0.59090909, 0.19318182, 0.61363636,
#        0.        , 0.125     , 0.28409091, 0.39772727, 0.42045455,
#        0.56818182, 0.18181818, 0.17045455, 0.21590909, 0.20454545,
#        0.71590909, 0.43181818, 0.23863636, 0.06818182, 0.51136364,
#        0.69318182, 0.36363636, 0.64772727, 0.55681818, 0.68181818,
#        0.70454545, 0.77272727, 0.65909091, 0.93181818, 0.72727273,
#        0.625     , 1.        , 0.79545455])

# %%
# StardartScaler

scaler_std = StandardScaler()
df_scaler_std = df.copy()
df_scaler_std[num_features] = scaler_std.fit_transform(df[num_features])
df_scaler_std.Oldpeak.unique()
# Out:
# array([-0.83243239,  0.10566353,  0.57471149,  1.04375945,  1.98185537,
#         2.91995129, -0.36338443,  1.51280741,  3.85804721, -0.08195566,
#        -0.17576525,  0.4809019 ,  1.13756904, -0.45719402, -0.64481321,
#         0.76233067,  1.23137863, -0.7386228 ,  0.66852108,  0.3870923 ,
#        -0.55100362,  0.85614026,  1.606617  , -1.67671872,  1.79423618,
#        -3.27148179, -2.23957627, -0.92624199,  0.01185394,  0.19947312,
#         1.41899782, -1.77052831, -1.86433791, -1.48909954, -1.58290913,
#         2.63852251,  0.29328271, -1.30148035, -2.70862423,  0.94994986,
#         2.45090333, -0.26957484,  2.07566496,  1.32518822,  2.35709374,
#         2.54471292,  3.10757047,  2.16947455,  4.42090476,  2.73233211,
#         1.88804578,  4.98376231,  3.29518966])

# %%
df_scaled = df.copy()
df_scaled[num_features] = df_scaler_std[num_features]

df_scaled
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina   Oldpeak ST_Slope  HeartDisease
# 0      172              N -0.832432       Up             0
# 1      156              N  0.105664     Flat             1
# 2       98              N -0.832432       Up             0
# 3      108              Y  0.574711     Flat             1
# 4      122              N -0.832432       Up             0
# ..     ...            ...       ...      ...           ...
# 913    132              N  0.293283     Flat             1
# 914    141              N  2.357094     Flat             1
# 915    115              Y  0.293283     Flat             1
# 916    174              N -0.832432     Flat             1
# 917    173              N -0.832432       Up             0
#
# [918 rows x 12 columns]

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of OneHotEncoder
df = df.astype({'Sex': 'category',
                'ChestPainType': 'category',
                'RestingECG': 'category',
                'ExerciseAngina': 'category',
                'ST_Slope': 'category',
                })
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    category
#  2   ChestPainType   918 non-null    category
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    category
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    category
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    category
#  11  HeartDisease    918 non-null    int64
# dtypes: category(5), float64(1), int64(6)
# memory usage: 62.6 KB

# %%
cat_features = df.select_dtypes(include=['category']).columns

df_cat_features = pd.get_dummies(df, columns=cat_features, drop_first=True)

cat_features
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %%
encoder = OneHotEncoder()

encode_features = encoder.fit_transform(df[cat_features])

encode_col = encoder.get_feature_names_out(cat_features)
encode_col
# Out:
# array(['Sex_F', 'Sex_M', 'ChestPainType_ASY', 'ChestPainType_ATA',
#        'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH',
#        'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_N',
#        'ExerciseAngina_Y', 'ST_Slope_Down', 'ST_Slope_Flat',
#        'ST_Slope_Up'], dtype=object)

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %%
#Функция по расчету тут

# %%
#Пример использования тут и объяснение принципа работы

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
df = pd.DataFrame(data)
df
# Out:
#    Рост  Вес
# 0   170   65
# 1   155   50
# 2   180   75
# 3   162   55
# 4   175   70

# %%
corr_pearson(df["Рост"], df["Вес"])
# Out:
# array([[0.96593129, 0.99674864],
#        [0.99674864, 1.03527033]])
